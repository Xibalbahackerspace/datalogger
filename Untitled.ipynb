# %%
from pylab import *
lineas = []

with open("DATALOG2.TXT") as fichero:
    # recorre línea a línea el archivo
    for linea in fichero:
        # muestra línea última leída
        #print(linea) 
        lineas.append(int(linea[:-1]))
#print(type(lineas[1]))
#print(lineas)

plt.plot(lineas)
plt.show()

# %%
plt.plot(lineas[90000:100000])
plt.show()

# %%
plt.plot(lineas[95600:98700])
plt.show()

# %%
plt.plot(lineas[130000:148000])
plt.show()
